# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

flats = pd.read_csv("Ukraine.csv")

# %%
# Are flats in older buildings tend to be cheaper?

flats["old_building"] = flats["year_of_building"] <= 2000

sns.barplot(data=flats, x="old_building", y="price")
plt.show()

# %%
sns.relplot(data=flats, x="year_of_building", y="price")
plt.show()

# %%
# Out:
#       num_of_rooms  area  living_area  kitchen_area  floor  floors_in_house  \
# 4388             1  44.0         20.0           8.0      2                4
#
#       year_of_building     price  city region  old_building
# 4388              1560  149996.0  Lviv   West          True
